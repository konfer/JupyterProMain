# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %% [markdown]
# 画图--基础

# %% [markdown]
# xticks 刻度
# ##plot（x,y）连接两个点
# #plt.  ----设置属性
# #plt.grid 增加网格
# #plt.show() 展示徒刑
# #plt.ylabel 坐标轴标签
# #plt.xticks 坐标轴显示范围 元组内列表构成显示范围替换
# #plt.xlim x轴上的显示范围

# %%
x = [1,2,3,1]
y = [1,3,0,1]

# %%
plt.plot(x,y)

plt.title('Triangle')
plt.ylabel('Y axis')
plt.xlabel('X axis')

#plt.xticks([1,4])
#plt.yticks([1,4])
#plt.xticks([1,6],['a','b'])

#plt.ylim([1,3])
#plt.xlim([1,3])

plt.grid(True,color='r')

plt.show()

# %% [markdown]
# 2. 画图——样式
#
# 数据线的样式设置
#
#      颜色缩写    全称
#      c          cyan
#      g          gree
#      k          black
#      m          magenta
#      r          red
#     w          white
#      y          yellow
#   例子：color=‘r’
#
#
#      线型缩写    含义
#      --         --虚线
#      -.         -.虚线
#      :          .虚线
#      -          实线
#   例子：linestyle='--'
#      marker类型参考
#      http://www.labri.fr/perso/nrougier/teaching/matplotlib/#line-properties

# %% [markdown]
# label="one" 对该行所在语句所画图形标识出标签，plt.legend()执行后生效
#
# marker=‘o’|'>'|'D'  在图形边缘处以对应图形标识
#
# plt.legend(loc='upper left') 指定标签位置

# %%
#plt.figure(figsize=(10,6))
plt.plot(x,y,color='r',linewidth='2',linestyle='--',marker='D', label='one')
plt.plot(np.array(x)+1,np.array(y)+1,color='g',linewidth='3',linestyle=':',marker='o', label='two')
plt.plot(np.array(x)+2,np.array(y)+3,color='k',linewidth='1',linestyle='-.',marker='>', label='three')

plt.grid(True)
plt.legend()
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# ### 创建图形figure---plt.figure()
# ###行列序号

# %% [markdown]
# ### 4 公式

# %%
import matplotlib.pyplot as plt

# %%
fig=plt.figure(1,figsize=(3,3))

# %%
ax=plt.subplot(111)
ann=ax.annotate("Test",
                xy=(0.2,0.2),
                xytext=(0.8,0.8),
                size=20,
                va="center",
                ha="center",
                bbox=dict(boxstyle="round4",fc="w"),
                arrowprops=dict(arrowstyle="-|>",
                               connectionstyle="arc3,rad=0.2",
                               fc="r"),
                )
ax.grid(True)
plt.show()

# %% [markdown]
# ### xy:箭头的位置
#
# xytext：标注的位置
#
# bbox:边框的样式
#
#     fc：边框颜色
#
# arrowprops:箭头样式

# %% [markdown]
# ### 5 画图---多子图位置

# %%
t = np.arange(0, 5, 0.2)

fig = plt.figure()#figsize=(10,6)

#行, 列, 序号
ax1 = fig.add_subplot(221) 
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(212)

ax1.plot(t, t, 'r--', t,t**2, 'bs', t, t**3, 'g^' )
ax1.grid(True)
ax1.set_title('plot')

ax2.semilogy(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
ax2.grid(True)
ax2.set_title('ylog')

ax3.loglog(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
ax3.grid(True)
ax3.set_title('loglog')

fig.suptitle('normal vs ylog vs loglog')
#fig.subplots_adjust(hspace=0.4)

plt.show()
